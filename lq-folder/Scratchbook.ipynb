# %% [markdown]
# **The data science pipeline process:**
# - Acquire the data
# - Prepare and clean data
# - Explore
# - Model & Evaluate
# - Recommendations

# %%
#Imports
import numpy as np
import pandas as pd

# %%
# acquire main csv
df= pd.read_csv('survey.csv')

# %%
# Looking at dataframe
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
#Looking at shape
df.shape
# Out:
# (1259, 27)

# %%
#Looking at datatypes and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
#creating loop to see amount of nulls in each column
for col in df:
    null_count = df[col].isna().sum()
    print(f'{col} has {null_count}')
# Out:
# Timestamp has 0
# Age has 0
# Gender has 0
# Country has 0
# state has 515
# self_employed has 18
# family_history has 0
# treatment has 0
# work_interfere has 264
# no_employees has 0
# remote_work has 0
# tech_company has 0
# benefits has 0
# care_options has 0
# wellness_program has 0
# seek_help has 0
# anonymity has 0
# leave has 0
# mental_health_consequence has 0
# phys_health_consequence has 0
# coworkers has 0
# supervisor has 0
# mental_health_interview has 0
# phys_health_interview has 0
# mental_vs_physical has 0
# obs_consequence has 0
# comments has 1095

# %%
# Looking at value counts for each column
for col in df:
    val_count = df[col].value_counts()
    print(f'{col} has {val_count}')
# Out:
# Timestamp has 2014-08-27 12:44:51    2
# 2014-08-27 15:24:47    2
# 2014-08-27 12:31:41    2
# 2014-08-27 12:54:11    2
# 2014-08-27 14:22:43    2
#                       ..
# 2014-08-27 18:59:44    1
# 2014-08-27 13:15:25    1
# 2014-08-28 20:12:08    1
# 2014-08-27 11:50:28    1
# 2014-08-27 11:41:50    1
# Name: Timestamp, Length: 1246, dtype: int64
# Age has  29             85
#  32             82
#  26             75
#  27             71
#  33             70
#  28             68
#  31             67
#  34             65
#  30             63
#  25             61
#  35             55
#  23             51
#  24             46
#  37             43
#  38             39
#  36             37
#  39             33
#  40             33
#  43             28
#  41             21
#  22             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  20              6
#  48              6
# ...

# %% [markdown]
# # 2016 Data

# %% [markdown]
# ## Acquire

# %%
# acquire newer 2016 mental health survey
df_2016= pd.read_csv('2016Survey/mental-heath-in-tech-2016_20161114.csv')

# %%
#Looking at dataframe
df_2016.head().T
# Out:
#                                                                                   0  \
# Are you self-employed?                                                            0
# How many employees does your company or organiz...                           26-100
# Is your employer primarily a tech company/organ...                                1
# Is your primary role within your company relate...                              NaN
# Does your employer provide mental health benefi...  Not eligible for coverage / N/A
# ...                                                                             ...
# What US state or territory do you live in?                                      NaN
# What country do you work in?                                         United Kingdom
# What US state or territory do you work in?                                      NaN
# Which of the following best describes your work...               Back-end Developer
# ...

# %%
#Looking at shape
df_2016.shape
# Out:
# (1433, 63)

# %%
#creating loop to see amount of nulls in each column
for col in df_2016:
    null_count = df_2016[col].isna().sum()
    print(f'{col} has {null_count}')
# Out:
# Are you self-employed? has 0
# How many employees does your company or organization have? has 287
# Is your employer primarily a tech company/organization? has 287
# Is your primary role within your company related to tech/IT? has 1170
# Does your employer provide mental health benefits as part of healthcare coverage? has 287
# Do you know the options for mental health care available under your employer-provided coverage? has 420
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)? has 287
# Does your employer offer resources to learn more about mental health concerns and options for seeking help? has 287
# Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer? has 287
# If a mental health issue prompted you to request a medical leave from work, asking for that leave would be: has 287
# ...

# %% [markdown]
# ### Takeaway:
# - Most of the columns has nulls
# - Decide whether to replace null values or to drop them
# - Will look at value counts for each column next to decide what to replace and what to drop

# %%
# Looking at value counts for each column
for col in df_2016:
    val_count = df_2016[col].value_counts()
    print(f'{col} has {val_count}')
# Out:
# Are you self-employed? has 0    1146
# 1     287
# Name: Are you self-employed?, dtype: int64
# How many employees does your company or organization have? has 26-100            292
# More than 1000    256
# 100-500           248
# 6-25              210
# 500-1000           80
# 1-5                60
# Name: How many employees does your company or organization have?, dtype: int64
# Is your employer primarily a tech company/organization? has 1.0    883
# 0.0    263
# Name: Is your employer primarily a tech company/organization?, dtype: int64
# Is your primary role within your company related to tech/IT? has 1.0    248
# 0.0     15
# Name: Is your primary role within your company related to tech/IT?, dtype: int64
# Does your employer provide mental health benefits as part of healthcare coverage? has Yes                                531
# I don't know                       319
# No                                 213
# Not eligible for coverage / N/A     83
# ...

# %% [markdown]
# ### Takeaway:
# - Narrow down to N. America and Europe only
# - Gender column: Need to make 3 groups: Male, Female, and other
# - Which of the following best describes your work position? column: will need to narrow down into categories to make it usable
# - Need to decide clean all columns or only columns we want to use?

# %% [markdown]
# ## Prepare

# %% [markdown]
# ## Explore

# %% [markdown]
# ## Model & Evaluate
